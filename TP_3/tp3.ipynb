# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
def FFT(y,dt):
    # Realiza la FFT de la señal y
    # array(complex) FFT(array complex y, int n, float t)
    # Entradas:
    #          y: vector de longitud N (array D)
    #          dt: intervalo de muestreo de la señal y
    # Salida:
    #          Y: resultado de FFT de y (array D)
    #          frec: frecuencia asociadoas a FFT(y)
    
    n = len (y)
    Y = np.fft.fft(y) #normalizada
    frec = np.fft.fftfreq(n,dt)
    return Y, frec

# %%
def cuadrada(senial):
    y = []
    for signal in senial:
        if signal == 1:
            valor_cuad = 1
        else:
            valor_cuad = 0
        y.append(valor_cuad)
    y = np.array(y)
    return(y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# Definir el tiempo de muestreo
t = np.linspace(0, 1, 50000, endpoint=False)

# Generar la señal cuadrada
senal_cuadrada1 = signal.square(2 * np.pi * 5 * t)
senal_cuadrada2 = signal.square(2 * np.pi * 5 * t, 0.1)

# Graficar la señal cuadrada
fig = plt.gcf()
fig.set_size_inches(18.5,10.5)
plt.plot(t, cuadrada(senal_cuadrada1))
plt.plot(t, cuadrada(senal_cuadrada2))
plt.xlim(0, 1)
plt.grid()
plt.show()

# %%
fft = np.fft.fft(cuadrada(senal_cuadrada2))

n = len(cuadrada(senal_cuadrada2))
frec = np.fft.fftfreq(n)


fig = plt.gcf()
fig.set_size_inches(18.5,10.5)

plt.subplot(2, 1, 1)
plt.plot(t, cuadrada(senal_cuadrada2), "r")
plt.title("señal original")

plt.subplot(2, 1, 2)
plt.plot(frec, np.abs(fft))
plt.xlim(-0.005,0.005)
plt.title("FFT de la señal")

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fft1 = np.fft.fft(cuadrada(senal_cuadrada1))

n1 = len(cuadrada(senal_cuadrada1))
freq1 = np.fft.fftfreq(n1)

fft2 = np.fft.fft(cuadrada(senal_cuadrada2))

n2 = len(cuadrada(senal_cuadrada2))
freq2 = np.fft.fftfreq(n2)

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)

plt.vlines(freq1, 0, np.abs(fft1), 'orange', label = 'Duty = 0.5', lw = 8)
plt.vlines(freq2, 0, np.abs(fft2), 'blue', label = 'Duty = 0.1', lw = 4)
plt.legend(), plt.xlabel("frec [Hz]"), plt.ylabel("x(f)")
plt.xlim(-0.003,0.003)
plt.title("FFT de la señal")

plt.grid()
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
puntos = 4001
pulso_cuad = np.zeros(4001)
pulso_cuad[0:1000] = 1
pulso_cuad[3001:4001] = 1

plt.figure(1)
plt.plot(np.arange(4001)/4000, pulso_cuad)

eje = np.arange(4001)

N = 10
coef_fourier = np.zeros(N)

for ind in range (N):
    coseno = np.cos(2 * np.pi * (ind + 1) * eje / 4000)
    coef = 2 * np.dot(coseno, pulso_cuad) / 4000
    coef_fourier[ind] = coef

eje_frec = np.arange(0.01, N + 0.01, 0.01)
envolvente = np.sin(0.5 * np.pi *eje_frec) / (0.5 * np.pi * eje_frec)

plt.figure(2)
plt.plot(eje_frec, envolvente, 'r', np.arange(1, N + 1), coef_fourier, 'ob')

# %%
# Crear una señal de ejemplo
temp = np.linspace(0, 0.5, 500)
senal = np.sin(40 * 2 * np.pi * temp) + 0.5 * np.sin(90 * 2 * np.pi * temp)

# Calcular la FFT
fft = np.fft.fft(senal)

# Calcular las frecuencias para los valores de la FFT
N = len(senal)
frecuencias = np.fft.fftfreq(N)

# Graficar la señal original y la FFT
plt.figure()

plt.subplot(2, 1, 1)
plt.plot(temp, senal)
plt.title('Señal Original')

plt.subplot(2, 1, 2)
plt.plot(frecuencias, np.abs(fft))
plt.title('FFT de la Señal')

plt.tight_layout()
plt.show()
