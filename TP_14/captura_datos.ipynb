# %% [markdown]
# ### Señales Electricas 2024
# ***
# #### Trabajo Practico 14

# %%
# %pip install pyserial
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import serial 
import matplotlib.pyplot as plt
import scipy.signal
from scipy.fft import fft, fftfreq, fftshift, ifft
from IPython.display import Audio

# %%
serial.Serial
# Out:
# serial.serialwin32.Serial

# %%
def tomaLecturas(puerto:str,cantidad:int,ancho:int=2,orden:str='little')-> np.ndarray:
    """
    Realiza la captura de una n datos de un puerto COM de la PC.
    
    Parameters:
    ----------
    puerto: str
        puerto de la PC de donde se leen los datos. ejmplo "COM6" 
    cantidad: int
        cantida de lecturas a realizar.
    ancho :int
        cantidad de byte a leidos en cada lectura
    orden: str
    
    Return:
    ------
    señal: array (1D)
        señal de capturada
    
    """
    with serial.Serial(puerto) as s:
        datos=s.read(ancho*cantidad)
    señal_capturada =np.array([ int.from_bytes(datos[ancho*i:ancho*(i+1)],orden,signed=False) for i in range(cantidad)]) 
    
    return señal_capturada

# %%
cantidad_bytes = 60*4096
datos = tomaLecturas("COM5",cantidad_bytes) # Cambiar segun el puerto de la pc.

# %% [markdown]
# SEÑAL SENO 1K

# %%
plt.plot(datos*3.3/2**12-1.58)
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
n=len(datos)
yf=fft(datos-1961)/n
xf=fftfreq(n,1/50000)

plt.plot(xf,np.abs(yf))
plt.xlim(-3000,3000)
# Out:
# (-3000.0, 3000.0)

# %% [markdown]
# SEÑAL SENO 5K

# %%
plt.plot(datos*3.3/2**12-26)
plt.xlim(100,180)
# Out:
# (100.0, 180.0)

# %%
n=len(datos)
yf=fft(datos-25500)/n
xf=fftfreq(n,1/50000)

plt.plot(xf,np.abs(yf))
plt.xlim(-7000,7000)
# Out:
# (-7000.0, 7000.0)

# %% [markdown]
# SEÑAL SENO 10K

# %%
plt.plot(datos*3.3/2**12-1.56)
plt.xlim(50150,50200)
# Out:
# (50150.0, 50200.0)

# %%
n=len(datos)
yf=fft(datos-1940)/n
xf=fftfreq(n,1/50000)

plt.plot(xf,np.abs(yf))
#plt.xlim(-7000,7000)

# %% [markdown]
# SEÑAL SENO 25K

# %%
plt.plot(datos*3.3/2**12-1.56)
plt.xlim(50110,50200)
# Out:
# (50110.0, 50200.0)

# %%
n=len(datos)
yf=fft(datos-1939)/n
xf=fftfreq(n,1/50000)

plt.plot(xf,np.abs(yf))
plt.xlim(-50000,50000)
# Out:
# (-50000.0, 50000.0)

# %% [markdown]
# SEÑAL SENO 30K

# %%
plt.plot(datos*3.3/2**10-120)
plt.xlim(50120,50200)
plt.ylim(-20,20)
# Out:
# (-20.0, 20.0)

# %%
n=len(datos)
yf=fft(datos-36500)/n
xf=fftfreq(n,1/50000)

plt.plot(xf,np.abs(yf))
#plt.xlim(-7000,7000)

# %% [markdown]
# SEÑAL SENO 40K

# %%
plt.plot(datos*3.3/2**12)
plt.xlim(50000,50200)
# Out:
# (50000.0, 50200.0)

# %%
n=len(datos)
yf=fft(datos-1939)/n
xf=fftfreq(n,1/50000)

plt.plot(xf,np.abs(yf))
plt.xlim(-30000,30000)
# Out:
# (-30000.0, 30000.0)

# %% [markdown]
# SEÑAL CUADRADA 1K

# %%
plt.plot(datos*3.3/2**12-1.58)
plt.xlim(50000,50200)
# Out:
# (50000.0, 50200.0)

# %%
n=len(datos)
yf=fft(datos-1910)/n
xf=fftfreq(n,1/50000)

plt.plot(xf,np.abs(yf))
#plt.xlim(-7000,7000)

# %% [markdown]
# SEÑAL AUDIO

# %%
plt.plot(datos*3.3/2**12)
#plt.xlim(50000,50200)

# %%
n=len(datos)
yf=fft(datos-1936)/n
xf=fftfreq(n,1/50000)

plt.plot(xf,np.abs(yf))
plt.xlim(-7000,7000)
# Out:
# (-7000.0, 7000.0)
